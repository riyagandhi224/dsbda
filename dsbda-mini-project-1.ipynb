# %% [markdown]
# **Use the following dataset and classify tweets into positive and negative tweets.
#  https://www.kaggle.com/ruchi798/data-science-tweets**

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
import os
print(os.listdir('/kaggle/input/datasets/ruchi798/data-science-tweets'))
# Out:
# ['tweets']

# %%
import os
print(os.listdir('/kaggle/input/datasets/ruchi798/data-science-tweets/tweets'))
# Out:
# ['data_science.csv', 'data_analysis.csv', 'data_visualization.csv']

# %%
import pandas as pd

path = '/kaggle/input/datasets/ruchi798/data-science-tweets/tweets/'

df1 = pd.read_csv(path + 'data_science.csv')
df2 = pd.read_csv(path + 'data_analysis.csv')
df3 = pd.read_csv(path + 'data_visualization.csv')

df = pd.concat([df1, df2, df3], ignore_index=True)

print(df.shape)
print(df.head())
# Out:
# (314092, 36)
#                     id      conversation_id               created_at  \
# 0  1406400408545804288  1406400396264943616  2021-06-20 05:26:01 IST
# 1  1406390341176016897  1406390341176016897  2021-06-20 04:46:01 IST
# 2  1406386311481774083  1406386311481774083  2021-06-20 04:30:00 IST
# 3  1406383545153638402  1406383545153638402  2021-06-20 04:19:01 IST
# 4  1406358632648818689  1406358632648818689  2021-06-20 02:40:01 IST
#
#          date      time  timezone              user_id         username  \
# 0  2021-06-20  05:26:01       530  1113747629282930688  ballouxfrancois
# 1  2021-06-20  04:46:01       530   788898706586275840     tdatascience
# 2  2021-06-20  04:30:00       530             19402238      sciencenews
# 3  2021-06-20  04:19:01       530   788898706586275840     tdatascience
# 4  2021-06-20  02:40:01       530   788898706586275840     tdatascience
#
#                     name place  ... geo source user_rt_id user_rt retweet_id  \
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

import re

def clean_text(text):
    text = re.sub(r"http\S+", "", str(text))
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#\w+", "", text)
    text = re.sub(r"[^a-zA-Z]", " ", text)
    text = text.lower()
    text = " ".join([word for word in text.split() if word not in stop_words])
    return text

df['clean_text'] = df['tweet'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from textblob import TextBlob

def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    return "Positive" if polarity >= 0 else "Negative"

df['sentiment'] = df['clean_text'].apply(get_sentiment)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000)
X = vectorizer.fit_transform(df['clean_text'])
y = df['sentiment']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9671436985625368
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.70      0.80      5878
#     Positive       0.97      0.99      0.98     56941
#
#     accuracy                           0.97     62819
#    macro avg       0.95      0.85      0.89     62819
# weighted avg       0.97      0.97      0.97     62819
